# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="vart  ligger somalia",
)
print(response.text)
# Out:
# Somalia ligger i **östra Afrika**, på en geografisk utskjutande del som kallas **Afrikas horn**.
#
# Det har en lång kustlinje längs **Indiska oceanen** i öster och **Adenviken** i norr.
#
# Länderna det gränsar till är:
# *   **Etiopien** i väster
# *   **Kenya** i sydväst
# *   **Djibouti** i nordväst

# %%
import lancedb

vector_db = lancedb.connect(uri = "knowledge_base")
vector_db.table_names()
# Out:
# []
